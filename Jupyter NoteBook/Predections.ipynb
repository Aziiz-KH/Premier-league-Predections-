# %%
import pandas as pd

# %%
import html5lib

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#    season       team
# 0    2023  Liverpool
# 1    2023  Liverpool
# 2    2023  Liverpool
# 3    2023  Liverpool
# 4    2023  Liverpool
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1540, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   96
# Crystal Palace              76
# Southampton                 76
# Leeds United                76
# Leicester City              76
# Everton                     76
# West Ham United             76
# Wolverhampton Wanderers     76
# Manchester City             76
# Chelsea                     76
# Brentford                   76
# Tottenham Hotspur           76
# Aston Villa                 76
# Brighton and Hove Albion    76
# Newcastle United            76
# Manchester United           76
# Arsenal                     76
# Fulham                      38
# Bournemouth                 38
# Nottingham Forest           38
# Burnley                     38
# Watford                     38
# Norwich City                38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 55  2022-04-30  12:30  Premier League  Matchweek 35  Sat  Away      W  1.0
# 57  2022-05-07  19:45  Premier League  Matchweek 36  Sat  Home      D  1.0
# 58  2022-05-10  20:00  Premier League  Matchweek 33  Tue  Away      W  2.0
# 60  2022-05-17  19:45  Premier League  Matchweek 37  Tue  Away      W  2.0
# 61  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga       opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# 0   1.0        Chelsea  ...  Match Report    NaN  13.0   1.0  17.8  0.0  0
# 1   1.0    Bournemouth  ...  Match Report    NaN  25.0   9.0  16.8  1.0  0
# 2   1.0  Newcastle Utd  ...  Match Report    NaN   9.0   4.0  17.2  1.0  0
# 3   0.0    Aston Villa  ...  Match Report    NaN  17.0   4.0  14.7  0.0  0
# 4   1.0         Wolves  ...  Match Report    NaN  16.0   5.0  15.8  0.0  0
# ..  ...            ...  ...           ...    ...   ...   ...   ...  ... ..
# 55  0.0  Newcastle Utd  ...  Match Report    NaN  24.0  10.0  17.7  2.0  0
# 57  1.0      Tottenham  ...  Match Report    NaN  22.0   3.0  19.6  1.0  0
# 58  1.0    Aston Villa  ...  Match Report    NaN  17.0   5.0  17.0  2.0  0
# 60  1.0    Southampton  ...  Match Report    NaN  24.0   5.0  18.6  0.0  0
# 61  1.0         Wolves  ...  Match Report    NaN  29.0   7.0  15.6  0.0  0
#
#    pkatt  season       team
# 0      0    2023  Liverpool
# 1      1    2023  Liverpool
# 2      0    2023  Liverpool
# 3      0    2023  Liverpool
# 4      0    2023  Liverpool
# ..   ...     ...        ...
# 55     0    2022  Liverpool
# 57     0    2022  Liverpool
# 58     0    2022  Liverpool
# 60     0    2022  Liverpool
# 61     0    2022  Liverpool
#
# [96 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     41
# Matchweek 12    41
# Matchweek 2     41
# Matchweek 19    41
# Matchweek 18    41
# Matchweek 17    41
# Matchweek 16    41
# Matchweek 15    41
# Matchweek 14    41
# Matchweek 13    41
# Matchweek 20    41
# Matchweek 11    41
# Matchweek 6     41
# Matchweek 10    41
# Matchweek 4     41
# Matchweek 5     41
# Matchweek 3     41
# Matchweek 7     41
# Matchweek 8     41
# Matchweek 9     41
# Matchweek 31    40
# Matchweek 32    40
# Matchweek 37    40
# Matchweek 36    40
# Matchweek 35    40
# Matchweek 28    40
# Matchweek 34    40
# Matchweek 33    40
# Matchweek 25    40
# Matchweek 30    40
# Matchweek 29    40
# Matchweek 27    40
# Matchweek 26    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...   fk  pk  pkatt  season          team venue_code  \
# 0   1.0         Chelsea  ...  0.0   0      0    2023     Liverpool          0
# 1   1.0     Bournemouth  ...  1.0   0      1    2023     Liverpool          1
# 2   1.0   Newcastle Utd  ...  1.0   0      0    2023     Liverpool          0
# 3   0.0     Aston Villa  ...  0.0   0      0    2023     Liverpool          1
# 4   1.0          Wolves  ...  0.0   0      0    2023     Liverpool          0
# ..  ...             ...  ...  ...  ..    ...     ...           ...        ...
# 38  2.0     Aston Villa  ...  0.0   0      0    2022  Norwich City          0
# 39  4.0        West Ham  ...  1.0   0      0    2022  Norwich City          1
# 40  3.0  Leicester City  ...  0.0   0      0    2022  Norwich City          0
# 41  1.0          Wolves  ...  0.0   0      0    2022  Norwich City          0
# 42  5.0       Tottenham  ...  0.0   0      0    2022  Norwich City          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        24   12         5       1
# ..      ...  ...       ...     ...
# 38        1   15         5       0
# 39       23   14         6       0
# 40       11   19         2       0
# 41       24   14         6       0
# 42       21   16         6       0
#
# [1540 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split =10, random_state=1)

# %%
train = matches[matches["date"] < '2023-04-01']

# %%
train
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga         opponent  ...   fk  pk  pkatt  season             team  \
# 1   0.0         West Ham  ...  1.0   1      1    2023  Manchester City
# 2   0.0      Bournemouth  ...  0.0   0      0    2023  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0   0      0    2023  Manchester City
# 4   2.0   Crystal Palace  ...  0.0   0      0    2023  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0   0      0    2023  Manchester City
# ..  ...              ...  ...  ...  ..    ...     ...              ...
# 38  2.0      Aston Villa  ...  0.0   0      0    2022     Norwich City
# 39  4.0         West Ham  ...  1.0   0      0    2022     Norwich City
# 40  3.0   Leicester City  ...  0.0   0      0    2022     Norwich City
# 41  1.0           Wolves  ...  0.0   0      0    2022     Norwich City
# 42  5.0        Tottenham  ...  0.0   0      0    2022     Norwich City
#
#    venue_code opp_code hour  day_code  target
# 1           0       23   16         6       1
# 2           1        2   15         5       1
# 3           0       16   16         6       0
# 4           1        7   15         5       1
# 5           1       18   19         2       1
# ..        ...      ...  ...       ...     ...
# 38          0        1   15         5       0
# 39          1       23   14         6       0
# 40          0       11   19         2       0
# 41          0       24   14         6       0
# 42          1       21   16         6       0
#
# [1300 rows x 32 columns]

# %%
test = matches[matches["date"] > '2023-04-01']

# %%
test
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L  1.0
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L  3.0
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L  0.0
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L  1.0
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D  4.0
#
#      ga         opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0   1.0          Chelsea  ...  0.0   0      0    2023    Liverpool          0
# 1   1.0      Bournemouth  ...  1.0   0      1    2023    Liverpool          1
# 2   1.0    Newcastle Utd  ...  1.0   0      0    2023    Liverpool          0
# 3   0.0      Aston Villa  ...  0.0   0      0    2023    Liverpool          1
# 4   1.0           Wolves  ...  0.0   0      0    2023    Liverpool          0
# ..  ...              ...  ...  ...  ..    ...     ...          ...        ...
# 42  3.0    Newcastle Utd  ...  0.0   0      0    2023  Southampton          0
# 43  4.0  Nott'ham Forest  ...  0.0   1      1    2023  Southampton          0
# 44  2.0           Fulham  ...  0.0   0      0    2023  Southampton          1
# 45  3.0         Brighton  ...  1.0   0      0    2023  Southampton          0
# 46  4.0        Liverpool  ...  1.0   0      0    2023  Southampton          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        24   12         5       1
# ..      ...  ...       ...     ...
# 42       16   14         6       0
# 43       18   20         0       0
# 44        9   15         5       0
# 45        4   14         6       0
# 46       12   16         6       0
#
# [226 rows x 32 columns]

# %%
test.to_csv("test.csv")

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5973451327433629

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 64         0          0 2023-04-09                  Arsenal        Liverpool
# 65         0          1 2023-04-16                  Arsenal         West Ham
# 66         0          0 2023-04-21                  Arsenal      Southampton
# 67         0          0 2023-04-26                  Arsenal  Manchester City
# 68         1          0 2023-05-02                  Arsenal          Chelsea
# ...      ...        ...        ...                      ...              ...
# 1466       0          0 2023-04-29  Wolverhampton Wanderers         Brighton
# 1467       1          0 2023-05-06  Wolverhampton Wanderers      Aston Villa
# 1468       0          0 2023-05-13  Wolverhampton Wanderers   Manchester Utd
# 1469       0          0 2023-05-20  Wolverhampton Wanderers          Everton
# 1470       0          0 2023-05-28  Wolverhampton Wanderers          Arsenal
#
#      result new_team
# 64        D  Arsenal
# 65        D  Arsenal
# 66        D  Arsenal
# 67        L  Arsenal
# 68        W  Arsenal
# ...     ...      ...
# 1466      L   Wolves
# 1467      W   Wolves
# 1468      L   Wolves
# 1469      D   Wolves
# 1470      L   Wolves
#
# [226 rows x 7 columns]

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           103  27
# 1            64  32

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5423728813559322

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W  4.0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W  5.0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W  5.0
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  2.0
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga         opponent  ...   fk  pk  pkatt  season             team  \
# 1   0.0         West Ham  ...  1.0   1      1    2023  Manchester City
# 2   0.0      Bournemouth  ...  0.0   0      0    2023  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0   0      0    2023  Manchester City
# 4   2.0   Crystal Palace  ...  0.0   0      0    2023  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0   0      0    2023  Manchester City
# ..  ...              ...  ...  ...  ..    ...     ...              ...
# 52  0.0     Leeds United  ...  0.0   0      0    2022  Manchester City
# 54  0.0    Newcastle Utd  ...  1.0   0      0    2022  Manchester City
# 55  1.0           Wolves  ...  0.0   0      0    2022  Manchester City
# 56  2.0         West Ham  ...  2.0   0      1    2022  Manchester City
# 57  2.0      Aston Villa  ...  1.0   0      0    2022  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       23   16         6       1
# 2           1        2   15         5       1
# 3           0       16   16         6       0
# 4           1        7   15         5       1
# 5           1       18   19         2       1
# ..        ...      ...  ...       ...     ...
# 52          0       10   17         5       1
# 54          1       16   16         6       1
# 55          0       24   20         2       1
# 56          0       23   14         6       0
# 57          1        1   16         6       1
#
# [76 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W  3.0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W  1.0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D  1.0
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   0.0  Leicester City  ...         5       1    3.333333    0.333333
# 6   0.0     Southampton  ...         5       0    3.666667    0.000000
# 8   0.0         Chelsea  ...         5       1    2.000000    0.000000
# 10  2.0       Liverpool  ...         6       0    0.666667    0.000000
# 11  0.0         Burnley  ...         5       1    1.000000    0.666667
# ..  ...             ...  ...       ...     ...         ...         ...
# 52  1.0    Leeds United  ...         5       1    3.000000    0.666667
# 54  0.0         Everton  ...         6       1    2.333333    0.666667
# 56  0.0         Chelsea  ...         6       1    2.666667    0.333333
# 57  1.0        Brighton  ...         2       0    2.000000    0.333333
# 58  1.0       Brentford  ...         6       0    1.666667    0.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4   19.666667    6.000000    16.866667   0.666667    0.000000       0.000000
# 6   22.000000    7.333333    15.866667   0.333333    0.000000       0.000000
# 8   22.000000    6.333333    15.166667   0.333333    0.000000       0.000000
# 10  18.666667    4.000000    15.933333   0.333333    0.000000       0.000000
# 11  14.333333    2.333333    16.833333   0.666667    0.000000       0.000000
# ..        ...         ...          ...        ...         ...            ...
# 52  13.666667    8.000000    15.433333   0.000000    0.333333       0.333333
# 54  14.666667    7.000000    16.366667   0.666667    0.333333       0.666667
# 56  14.000000    5.666667    18.100000   1.333333    0.000000       0.333333
# 57  13.666667    4.000000    18.933333   1.333333    0.000000       0.333333
# 58  12.333333    3.333333    17.333333   0.666667    0.000000       0.000000
#
# [73 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 4   Sat  Home      W  1.0  0.0    Norwich City  ...
#                         5   Sat  Away      W  1.0  0.0         Burnley  ...
#                         7   Sun  Home      W  3.0  1.0       Tottenham  ...
#                         8   Sat  Away      D  0.0  0.0        Brighton  ...
#                         9   Mon  Home      D  2.0  2.0  Crystal Palace  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 39  Sat  Away      L  0.0  6.0        Brighton  ...
#                         40  Sat  Home      W  1.0  0.0     Aston Villa  ...
#                         41  Sat  Away      L  0.0  2.0  Manchester Utd  ...
#                         42  Sat  Home      D  1.0  1.0         Everton  ...
#                         43  Sun  Away      L  0.0  5.0         Arsenal  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5       1    0.000000    3.000000
#                         5          5       1    0.333333    2.333333
#                         7          6       1    0.666667    1.666667
#                         8          5       0    1.666667    0.333333
#                         9          0       0    1.333333    0.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 39         5       0    1.666667    0.666667
#                         40         5       1    1.000000    2.666667
#                         41         5       0    1.000000    2.000000
#                         42         5       0    0.333333    2.666667
#                         43         6       0    0.666667    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.833333   0.333333
#                         5   12.333333    3.000000    14.133333   0.333333
#                         7   14.666667    3.000000    14.800000   0.666667
#                         8   18.333333    5.333333    18.433333   0.666667
#                         9   11.000000    4.000000    19.833333   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 39  11.666667    4.666667    18.700000   0.666667
#                         40  11.333333    2.333333    18.800000   0.666667
#                         41   8.000000    2.000000    17.766667   0.000000
#                         42   7.000000    1.333333    15.600000   0.000000
#                         43   8.000000    2.333333    15.333333   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.000000       0.000000
#                         5     0.000000       0.000000
#                         7     0.000000       0.000000
#                         8     0.000000       0.000000
#                         9     0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 39    0.333333       0.333333
#                         40    0.333333       0.333333
#                         41    0.333333       0.333333
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#
# [1471 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L  0.0
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  1.0
# 41 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L  0.0
# 42 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D  1.0
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   0.0    Norwich City  ...         5       1    0.000000    3.000000
# 5   0.0         Burnley  ...         5       1    0.333333    2.333333
# 7   1.0       Tottenham  ...         6       1    0.666667    1.666667
# 8   0.0        Brighton  ...         5       0    1.666667    0.333333
# 9   2.0  Crystal Palace  ...         0       0    1.333333    0.333333
# ..  ...             ...  ...       ...     ...         ...         ...
# 39  6.0        Brighton  ...         5       0    1.666667    0.666667
# 40  0.0     Aston Villa  ...         5       1    1.000000    2.666667
# 41  2.0  Manchester Utd  ...         5       0    1.000000    2.000000
# 42  1.0         Everton  ...         5       0    0.333333    2.666667
# 43  5.0         Arsenal  ...         6       0    0.666667    1.000000
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 5   12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 7   14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 8   18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 9   11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ..        ...         ...          ...        ...         ...            ...
# 39  11.666667    4.666667    18.700000   0.666667    0.333333       0.333333
# 40  11.333333    2.333333    18.800000   0.666667    0.333333       0.333333
# 41   8.000000    2.000000    17.766667   0.000000    0.333333       0.333333
# 42   7.000000    1.333333    15.600000   0.000000    0.000000       0.000000
# 43   8.000000    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [1471 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1466 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L  0.0
# 1467 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  1.0
# 1468 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L  0.0
# 1469 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D  1.0
# 1470 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#        ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     0.0    Norwich City  ...         5       1    0.000000    3.000000
# 1     0.0         Burnley  ...         5       1    0.333333    2.333333
# 2     1.0       Tottenham  ...         6       1    0.666667    1.666667
# 3     0.0        Brighton  ...         5       0    1.666667    0.333333
# 4     2.0  Crystal Palace  ...         0       0    1.333333    0.333333
# ...   ...             ...  ...       ...     ...         ...         ...
# 1466  6.0        Brighton  ...         5       0    1.666667    0.666667
# 1467  0.0     Aston Villa  ...         5       1    1.000000    2.666667
# 1468  2.0  Manchester Utd  ...         5       0    1.000000    2.000000
# 1469  1.0         Everton  ...         5       0    0.333333    2.666667
# 1470  5.0         Arsenal  ...         6       0    0.666667    1.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 1     12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 2     14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 3     18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 4     11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ...         ...         ...          ...        ...         ...            ...
# 1466  11.666667    4.666667    18.700000   0.666667    0.333333       0.333333
# 1467  11.333333    2.333333    18.800000   0.666667    0.333333       0.333333
# 1468   8.000000    2.000000    17.766667   0.000000    0.333333       0.333333
# 1469   7.000000    1.333333    15.600000   0.000000    0.000000       0.000000
# 1470   8.000000    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [1471 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-04-01']
    test = data[data["date"] > '2023-04-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6081081081081081

# %%
combined
# Out:
#       actual  predicted
# 64         0          0
# 65         0          1
# 66         0          0
# 67         0          0
# 68         1          0
# ...      ...        ...
# 1466       0          0
# 1467       1          0
# 1468       0          0
# 1469       0          0
# 1470       0          0
#
# [226 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date","team", "opponent","result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 64         0          0 2023-04-09                  Arsenal        Liverpool
# 65         0          1 2023-04-16                  Arsenal         West Ham
# 66         0          0 2023-04-21                  Arsenal      Southampton
# 67         0          0 2023-04-26                  Arsenal  Manchester City
# 68         1          0 2023-05-02                  Arsenal          Chelsea
# ...      ...        ...        ...                      ...              ...
# 1466       0          0 2023-04-29  Wolverhampton Wanderers         Brighton
# 1467       1          0 2023-05-06  Wolverhampton Wanderers      Aston Villa
# 1468       0          0 2023-05-13  Wolverhampton Wanderers   Manchester Utd
# 1469       0          0 2023-05-20  Wolverhampton Wanderers          Everton
# 1470       0          0 2023-05-28  Wolverhampton Wanderers          Arsenal
#
#      result
# 64        D
# 65        D
# 66        D
# 67        L
# 68        W
# ...     ...
# 1466      L
# 1467      W
# 1468      L
# 1469      D
# 1470      L
#
# [226 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 64         0          0 2023-04-09                  Arsenal        Liverpool
# 65         0          1 2023-04-16                  Arsenal         West Ham
# 66         0          0 2023-04-21                  Arsenal      Southampton
# 67         0          0 2023-04-26                  Arsenal  Manchester City
# 68         1          0 2023-05-02                  Arsenal          Chelsea
# ...      ...        ...        ...                      ...              ...
# 1466       0          0 2023-04-29  Wolverhampton Wanderers         Brighton
# 1467       1          0 2023-05-06  Wolverhampton Wanderers      Aston Villa
# 1468       0          0 2023-05-13  Wolverhampton Wanderers   Manchester Utd
# 1469       0          0 2023-05-20  Wolverhampton Wanderers          Everton
# 1470       0          0 2023-05-28  Wolverhampton Wanderers          Arsenal
#
#      result new_team
# 64        D  Arsenal
# 65        D  Arsenal
# 66        D  Arsenal
# 67        L  Arsenal
# 68        W  Arsenal
# ...     ...      ...
# 1466      L   Wolves
# 1467      W   Wolves
# 1468      L   Wolves
# 1469      D   Wolves
# 1470      L   Wolves
#
# [226 rows x 7 columns]

# %%
combined.to_csv("combined.csv")

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2023-04-09                  Arsenal
# 1           0            1 2023-04-16                  Arsenal
# 2           0            0 2023-04-21                  Arsenal
# 3           0            0 2023-04-26                  Arsenal
# 4           1            0 2023-05-02                  Arsenal
# ..        ...          ...        ...                      ...
# 191         0            0 2023-04-29  Wolverhampton Wanderers
# 192         1            0 2023-05-06  Wolverhampton Wanderers
# 193         0            0 2023-05-13  Wolverhampton Wanderers
# 194         0            0 2023-05-20  Wolverhampton Wanderers
# 195         0            0 2023-05-28  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0          Liverpool        D    Arsenal         0            0
# 1           West Ham        D    Arsenal         0            0
# 2        Southampton        D    Arsenal         0            0
# 3    Manchester City        L    Arsenal         1            1
# 4            Chelsea        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 191         Brighton        L     Wolves         1            1
# 192      Aston Villa        W     Wolves         0            0
# 193   Manchester Utd        L     Wolves         1            1
# 194          Everton        D     Wolves         0            0
# 195          Arsenal        L     Wolves         1            0
#
#                        team_y opponent_y result_y       new_team_y
# 0                   Liverpool    Arsenal        D        Liverpool
# 1             West Ham United    Arsenal        D         West Ham
# 2                 Southampton    Arsenal        D      Southampton
# 3             Manchester City    Arsenal        W  Manchester City
# 4                     Chelsea    Arsenal        L          Chelsea
# ..                        ...        ...      ...              ...
# 191  Brighton and Hove Albion     Wolves        W         Brighton
# 192               Aston Villa     Wolves        L      Aston Villa
# 193         Manchester United     Wolves        W   Manchester Utd
# 194                   Everton     Wolves        D          Everton
# 195                   Arsenal     Wolves        W          Arsenal
#
# [196 rows x 13 columns]

# %%
test
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L  1.0
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L  3.0
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L  0.0
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L  1.0
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D  4.0
#
#      ga         opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0   1.0          Chelsea  ...  0.0   0      0    2023    Liverpool          0
# 1   1.0      Bournemouth  ...  1.0   0      1    2023    Liverpool          1
# 2   1.0    Newcastle Utd  ...  1.0   0      0    2023    Liverpool          0
# 3   0.0      Aston Villa  ...  0.0   0      0    2023    Liverpool          1
# 4   1.0           Wolves  ...  0.0   0      0    2023    Liverpool          0
# ..  ...              ...  ...  ...  ..    ...     ...          ...        ...
# 42  3.0    Newcastle Utd  ...  0.0   0      0    2023  Southampton          0
# 43  4.0  Nott'ham Forest  ...  0.0   1      1    2023  Southampton          0
# 44  2.0           Fulham  ...  0.0   0      0    2023  Southampton          1
# 45  3.0         Brighton  ...  1.0   0      0    2023  Southampton          0
# 46  4.0        Liverpool  ...  1.0   0      0    2023  Southampton          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        24   12         5       1
# ..      ...  ...       ...     ...
# 42       16   14         6       0
# 43       18   20         0       0
# 44        9   15         5       0
# 45        4   14         6       0
# 46       12   16         6       0
#
# [226 rows x 32 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    32
# 0    20
# Name: count, dtype: int64

# %%
32/(32+20)
# Out:
# 0.6153846153846154

# %%
merged.to_csv("merged.csv")
